# %%
pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 69.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 5.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.5 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import pickle
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
def make_prediction(Year,Kilometers_Driven,Mileage,Engine,Power,Seats,Location_Ahmedabad,Location_Bangalore,Location_Chennai,Location_Coimbatore,Location_Delhi,Location_Hyderabad,Location_Jaipur,Location_Kochi,Location_Kolkata,Location_Mumbai,Location_Pune,Fuel_Type_CNG,Fuel_Type_Diesel,Fuel_Type_LPG,Fuel_Type_Petrol,Transmission_Automatic,Transmission_Manual,Owner_Type_First, Owner_Type_Fourth_and_Above,Owner_Type_Second,Owner_Type_Third,Company_Ambassador,Company_Audi,Company_BMW,Company_Bentley,Company_Chevrolet,Company_Datsun,Company_Fiat,Company_Force,Company_Ford,Company_Honda,Company_Hyundai,Company_Isuzu,Company_Jaguar,Company_Jeep,Company_Lamborghini,Company_Land,Company_Mahindra, Company_Maruti,Company_Mercedes_Benz,Company_Mini,Company_Mitsubishi,Company_Nissan,Company_Porsche,Company_Renault,Company_Skoda,Company_Tata,Company_Toyota,Company_Volkswagen,Company_Volvo):
    with open("/content/model1.pkl", "rb") as f:
        clf  = pickle.load(f)
        inputs=[Year,Kilometers_Driven,Mileage,Engine,Power,Seats,Location_Ahmedabad,Location_Bangalore,Location_Chennai,Location_Coimbatore,Location_Delhi,Location_Hyderabad,Location_Jaipur,Location_Kochi,Location_Kolkata,Location_Mumbai,Location_Pune,Fuel_Type_CNG,Fuel_Type_Diesel,Fuel_Type_LPG,Fuel_Type_Petrol,Transmission_Automatic,Transmission_Manual,Owner_Type_First, Owner_Type_Fourth_and_Above,Owner_Type_Second,Owner_Type_Third,Company_Ambassador,Company_Audi,Company_BMW,Company_Bentley,Company_Chevrolet,Company_Datsun,Company_Fiat,Company_Force,Company_Ford,Company_Honda,Company_Hyundai,Company_Isuzu,Company_Jaguar,Company_Jeep,Company_Lamborghini,Company_Land,Company_Mahindra, Company_Maruti,Company_Mercedes_Benz,Company_Mini,Company_Mitsubishi,Company_Nissan,Company_Porsche,Company_Renault,Company_Skoda,Company_Tata,Company_Toyota,Company_Volkswagen,Company_Volvo]
        vcols=[]
        # for i in range(len(inputs)):
        #   if inputs[i] == True:
        #     vcols[i]=1
        #   elif inputs[i] == False:
        #     vcols[i]=0
        #   else:
        #     vcols[i]=input[i]
          
        for i in inputs:
          if i == True:
            vcols.append(int(1))
          elif i == False:
            vcols.append(int(0))
          else:
            vcols.append(i)

        input=np.array(vcols)
        input=input.reshape(1,-1)
        #vcols=vcols.reshape(1,-1)
        preds = clf.predict(input)
        #preds = clf.predict(vcols)
    return preds

Year_input = gr.Number(label = "Year")
Kilometers_Driven_input = gr.Slider(0, 10000000, value=4, label="Kilometers Driven")
Mileage_input = gr.Number(label = "Mileage in kmpl")
Engine_input = gr.Number(label = "Engine in CC")
Power_input = gr.Number(label = "Power in bhp")
Seats_input = gr.Number(label = "No of seats")
locations = ['Location_Ahmedabad', 'Location_Bangalore', 'Location_Chennai',
       'Location_Coimbatore', 'Location_Delhi', 'Location_Hyderabad',
       'Location_Jaipur', 'Location_Kochi', 'Location_Kolkata',
       'Location_Mumbai', 'Location_Pune']

for i in locations:
  globals()['i%s' % i] = gr.Checkbox(label=i)
 
fuels=['Fuel_Type_CNG', 'Fuel_Type_Diesel',
       'Fuel_Type_LPG', 'Fuel_Type_Petrol']

for i in fuels:
  globals()['i%s' % i] = gr.Checkbox(label=i)

transmissions=['Transmission_Automatic',
       'Transmission_Manual']

for i in transmissions:
  globals()['i%s' % i] = gr.Checkbox(label=i)
  0

owner=['Owner_Type_First', 'Owner_Type_Fourth_and_Above',
       'Owner_Type_Second', 'Owner_Type_Third']

for i in owner:
  globals()['i%s' % i] = gr.Checkbox(label=i)
     
company=['Company_Ambassador',
       'Company_Audi', 'Company_BMW', 'Company_Bentley', 'Company_Chevrolet',
       'Company_Datsun', 'Company_Fiat', 'Company_Force', 'Company_Ford',
       'Company_Honda', 'Company_Hyundai', 'Company_Isuzu', 'Company_Jaguar',
       'Company_Jeep', 'Company_Lamborghini', 'Company_Land',
       'Company_Mahindra', 'Company_Maruti', 'Company_Mercedes_Benz',
       'Company_Mini', 'Company_Mitsubishi', 'Company_Nissan',
       'Company_Porsche', 'Company_Renault', 'Company_Skoda', 'Company_Tata',
       'Company_Toyota', 'Company_Volkswagen', 'Company_Volvo']

for i in company:
  globals()['i%s' % i] = gr.Checkbox(label=i)

output = gr.Textbox()

app = gr.Interface(fn = make_prediction, inputs=[Year_input,Kilometers_Driven_input,Mileage_input,Engine_input,Power_input,Seats_input,iLocation_Ahmedabad,iLocation_Bangalore,iLocation_Chennai,iLocation_Coimbatore,iLocation_Delhi,iLocation_Hyderabad,iLocation_Jaipur,iLocation_Kochi,iLocation_Kolkata,iLocation_Mumbai,iLocation_Pune,iFuel_Type_CNG,iFuel_Type_Diesel,iFuel_Type_LPG,iFuel_Type_Petrol,iTransmission_Automatic,iTransmission_Manual,iOwner_Type_First, iOwner_Type_Fourth_and_Above,iOwner_Type_Second,iOwner_Type_Third,iCompany_Ambassador,iCompany_Audi,iCompany_BMW,iCompany_Bentley,iCompany_Chevrolet,iCompany_Datsun,iCompany_Fiat,iCompany_Force,iCompany_Ford,iCompany_Honda,iCompany_Hyundai,iCompany_Isuzu,iCompany_Jaguar,iCompany_Jeep,iCompany_Lamborghini,iCompany_Land,iCompany_Mahindra, iCompany_Maruti,iCompany_Mercedes_Benz,iCompany_Mini,iCompany_Mitsubishi,iCompany_Nissan,iCompany_Porsche,iCompany_Renault,iCompany_Skoda,iCompany_Tata,iCompany_Toyota,iCompany_Volkswagen,iCompany_Volvo], outputs=output)
app.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
